# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("airline_2019.csv")

# %%
df.head(500)
# Out:
#         FL_DATE  OP_CARRIER_AIRLINE_ID TAIL_NUM ORIGIN ORIGIN_CITY_NAME  \
# 0    2019-04-01                  20416   N605NK    BWI    Baltimore, MD
# 1    2019-04-01                  20416   N605NK    DTW      Detroit, MI
# 2    2019-04-01                  20416   N605NK    BWI    Baltimore, MD
# 3    2019-04-01                  20416   N605NK    MCO      Orlando, FL
# 4    2019-04-01                  20416   N637NK    LAS    Las Vegas, NV
# ..          ...                    ...      ...    ...              ...
# 495  2019-04-01                  19805   N834AW    PHX      Phoenix, AZ
# 496  2019-04-01                  19805   N557UW    BDL     Hartford, CT
# 497  2019-04-01                  19805   N826AW    ATL      Atlanta, GA
# 498  2019-04-01                  19805   N103US    CLT    Charlotte, NC
# 499  2019-04-01                  19805   N703UW    CLT    Charlotte, NC
#
#     ORIGIN_STATE_NM DEST  DEST_CITY_NAME   DEST_STATE_NM  CRS_DEP_TIME  ...  \
# ...

# %%
df.shape
# Out:
# (7373570, 26)

# %%
df.tail()
# Out:
#             FL_DATE  OP_CARRIER_AIRLINE_ID TAIL_NUM ORIGIN   ORIGIN_CITY_NAME  \
# 7373565  2019-03-31                  19930   N524VA    SFO  San Francisco, CA
# 7373566  2019-03-31                  19930   N529VA    SAN      San Diego, CA
# 7373567  2019-03-31                  19930   N528VA    SFO  San Francisco, CA
# 7373568  2019-03-31                  19930   N524VA    SAN      San Diego, CA
# 7373569  2019-03-31                  19930   N364VA    SFO  San Francisco, CA
#
#         ORIGIN_STATE_NM DEST     DEST_CITY_NAME DEST_STATE_NM  CRS_DEP_TIME  \
# 7373565      California  SAN      San Diego, CA    California          1830
# 7373566      California  SFO  San Francisco, CA    California          1740
# 7373567      California  SAN      San Diego, CA    California          2140
# 7373568      California  SFO  San Francisco, CA    California          2050
# 7373569      California  LAX    Los Angeles, CA    California          1100
#
# ...
